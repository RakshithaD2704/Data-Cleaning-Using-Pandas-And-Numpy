# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## load data

# %%
df = pd.read_csv("/content/chipotle.tsv",sep='\t')

# %% [markdown]
# ## data process

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.isna()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %% [markdown]
# ## Quantity of each item

# %%
c = df.groupby('item_name').sum()
c = c.sort_values(['quantity'], ascending = False)
c.head()
# Out:
# <ipython-input-13-b1d1ad1fdba5>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c = df.groupby('item_name').sum()
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506
# Steak Burrito          328437       386
# Canned Soft Drink      304753       351

# %% [markdown]
# ## What was the most ordered itemin the choice_description column?

# %%
c = df.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending = False)
c.head(1)
# Out:
# <ipython-input-14-e2f2d5fcd231>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   c = df.groupby('choice_description').sum()
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# ## How many items were ordered in total?

# %%
total_items_ordered = df.quantity.sum()
total_items_ordered
# Out:
# 4972

# %% [markdown]
# ## How much was the revenue for the period in the dataset?

# %%
df["item_price"]= df["item_price"].astype(str).replace('$', '').astype(float)

# %%
revenue = df['item_price'].sum()
print('revenue was: $',revenue)
# Out:
# revenue was: $ 34500.16

# %% [markdown]
# ## How many orders were made in the period?

# %%
orders = df.order_id.value_counts().count()
orders
# Out:
# 1834

# %% [markdown]
# ## what is the average revenue amount per order?

# %%
df['revenue'] = df['quantity'] * df['item_price']
d = order_grouped = df.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# <ipython-input-34-eb65c17d6487>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d = order_grouped = df.groupby(by=['order_id']).sum()
# 21.39423118865867

# %% [markdown]
# ## How many different items are sold?

# %%
df.item_name.value_counts().count()
# Out:
# 50

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 0                                                   NaN        2.39     2.39
# ...
